# %%
import numpy as np

# %%
lst = [1,2,3,4]
lst = [[1,2,3], [4,5,6], [7,8,9]]

# %%
arr =np.array(lst)
# arr
np.array
print arr
# Out:
# [[1 2 3]
#  [4 5 6]
#  [7 8 9]]

# %%
big_lst = range(100000)
arr = np.array(big_lst)
arr.sum()
# Out:
# 704982704

# %%
print np.var(a=arr,axis=1, ddof=0)
print np.var(a=arr,axis=1, ddof=1)
np.var([1,2,3])
# Out:
# [ 0.66666667  0.66666667  0.66666667]
# [ 1.  1.  1.]
# 0.66666666666666663

# %%
mat = np.reshape(np.arange(9), (3,3))

print mat 
np.sum?
np.sum(mat,1)
# Out:
# [[0 1 2]
#  [3 4 5]
#  [6 7 8]]
# array([ 3, 12, 21])

# %%
mat2 = mat ** 3
print  mat2
print mat[0, :]
mat[0, :] + mat2
# Out:
# [[  0   1   8]
#  [ 27  64 125]
#  [216 343 512]]
# [0 1 2]
# array([[  0,   2,  10],
#        [ 27,  65, 127],
#        [216, 344, 514]])

# %%
lst = [1,4,7]
lst[:] == 4
arr == 4
np.random.rand(5)
# Out:
# array([ 0.96312537,  0.07727133,  0.7982469 ,  0.93881782,  0.28990956])

# %%
arr = np.arange(4)
print arr == 4
lst = range(4)
print lst == 4
# Out:
# [False False False False]
# False

# %%
import pandas as pd
from pandas import DataFrame, Series 
values = [1,2,3]
labels = ['Cashews', 'Almonds', 'Peanuts']
s = Series(values, labels)
print Series(dict(zip(labels, values)))
print s
print type(s.values)
df = pd.DataFrame([[1,2,3], [4,5,6],
                [7,8,9]], 
                index=['a', 'b', 'c'], 
                columns = labels)
df.ix['a',:]
df.index
# Out:
# Almonds    2
# Cashews    1
# Peanuts    3
# Cashews    1
# Almonds    2
# Peanuts    3
# <type 'numpy.ndarray'>
# Index([a, b, c], dtype=object)

# %%
from pandas import Panel
p = Panel({'x':df, 'y':df**2})
print p
print p.items
print p.major_axis
print p.minor_axis
p.ix[:, 'a',  :]
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 2 (items) x 3 (major_axis) x 3 (minor_axis)
# Items axis: x to y
# Major_axis axis: a to c
# Minor_axis axis: Cashews to Peanuts
# Index([x, y], dtype=object)
# Index([a, b, c], dtype=object)
# Index([Cashews, Almonds, Peanuts], dtype=object)
#          x  y
# Cashews  1  1
# Almonds  2  4
# Peanuts  3  9

# %%
d = DataFrame( {'col1' : Series(['A', 'B', 'A', 'B']), 
                'col2' : np.random.randn(4) })
d[d.col1 == 'A']
d.ix[2,1]
d.ix[d.col1 != 'A',1]
# Out:
# 1   -0.183176
# 3    0.565332
# Name: col2

# %%
path = 'https://dl.dropbox.com/u/22164876/data.csv'
# df = pd.read_csv(path)

df.shape
df.index
df.columns
df.head()
# Out:
#    Cashews  Almonds  Peanuts
# a        1        2        3
# b        4        5        6
# c        7        8        9

# %%
# df = pd.read_csv(path,index_col=['Date', 'Time'])
df.index[:5]
df.index[0]
df.head()
# Out:
#                           Price  Volume Exchange Code Sales Condition  \
# Date       Time
# 11/01/2011 08:04:56.364  104.55     100             P               T
#            08:53:07.459  104.43     150             T              FT
#            08:53:09.284  104.43     100             T              FT
#            08:54:03.921  104.50     100             P              FT
#            08:58:06.162  104.46    1000             Z               T
#
#                          Correction Indicator  Sequence Number  \
# Date       Time
# 11/01/2011 08:04:56.364                     0              196
#            08:53:07.459                     0              316
#            08:53:09.284                     0              317
#            08:54:03.921                     0              318
#            08:58:06.162                     0              322
#
#                         Trade Stop Indicator Source of Trade  \
# Date       Time
# 11/01/2011 08:04:56.364                    N               C
#            08:53:07.459                    N               C
#            08:53:09.284                    N               C
#            08:54:03.921                    N               C
#            08:58:06.162                    N               C
#
#                         MDS 127 / TRF (Trade Reporting Facility) (*)  \
# Date       Time
# 11/01/2011 08:04:56.364                                          NaN
#            08:53:07.459                                          NaN
#            08:53:09.284                                          NaN
#            08:54:03.921                                          NaN
#            08:58:06.162                                          NaN
#
#                         Exclude Record Flag  Filtered Price
# Date       Time
# 11/01/2011 08:04:56.364                 NaN             NaN
#            08:53:07.459                 NaN             NaN
#            08:53:09.284                 NaN             NaN
#            08:54:03.921                 NaN             NaN
#            08:58:06.162                 NaN             NaN

# %%
ticks = pd.read_csv(path, parse_dates={'ts': ['Date', 'Time']}, index_col='ts')
ticks.index
ticks.index[0]
isinstance(ticks.index[0], datetime.datetime)
ticks.index[0].nanosecond

sq_price = ticks.Price ** 2
print np.sqrt(sq_price.mean())

sq_vol = ticks.Volume ** 2
print np.sqrt(sq_vol.mean())

print ticks['Price'].std(ddof = 0)
print ticks['Price'].std(ddof = 1)
mean = ticks.Price.mean()
std = ticks.Price.std(ddof = 0)
uncentered = np.sqrt(mean ** 2 + std **2)
uncentered
# Out:
# 104.128195608
# 2719.55317408
# 0.195350524576
# 0.195357200373
# 104.12819560792252

# %%
ticks.describe()
ticks.Price.count()
ticks.mean(axis=1)
# Out:
# ts
# 2011-11-01 08:04:56.364000    100.1375
# 2011-11-01 08:53:07.459000    142.6075
# 2011-11-01 08:53:09.284000    130.3575
# 2011-11-01 08:54:03.921000    130.6250
# 2011-11-01 08:58:06.162000    356.6150
# 2011-11-01 08:58:06.162000    356.8650
# 2011-11-01 08:58:06.162000    357.1150
# 2011-11-01 08:58:06.164000    357.3650
# 2011-11-01 08:58:06.164000    357.6150
# 2011-11-01 09:28:59.153000    166.5425
# 2011-11-01 09:29:53.651000    272.3252
# 2011-11-01 09:30:00.278000    341.0575
# 2011-11-01 09:30:00.278000    341.3075
# 2011-11-01 09:30:00.384000    234.8075
# 2011-11-01 09:30:00.384000    227.8075
# ...
# 2011-11-03 16:00:00.413000    17328.4500
# 2011-11-03 16:00:00.413000    17759.4500
# 2011-11-03 16:00:00.413000    17753.9500
# 2011-11-03 16:00:00.413000    17754.2000
# 2011-11-03 16:00:00.413000    17504.4500
# 2011-11-03 16:00:00.413000    17629.7000
# 2011-11-03 16:00:00.413000    19418.2000
# 2011-11-03 16:00:00.413000    25685.4500
# 2011-11-03 16:00:02.899000    17459.9550
# 2011-11-03 16:00:03.355000    17362.7150
# 2011-11-03 16:06:40.064000    26212.7000
# 2011-11-03 16:09:45.824000    17398.9525
# 2011-11-03 16:09:45.826000    17849.2025
# 2011-11-03 16:09:47.832000    17399.4525
# 2011-11-03 16:09:47.834000    17863.9525
# Length: 14632

# %%
df = ticks.ix[:1000, ['Price', 'Volume']]
# df.sum()
# df.apply(lambda x: x.sum())
df.applymap(lambda x: x.sum()).head()
df.head()
df.head().applymap(lambda x: x**2)
df.ix[:5] - df.ix[:5]
# Out:
# /home/ubuntu/anaconda/lib/python2.7/site-packages/pandas/core/frame.py:3576: FutureWarning: rename with inplace=True  will return None from pandas 0.11 onward
#   " from pandas 0.11 onward", FutureWarning)
#                             Price  Volume
# ts
# 2011-11-01 08:04:56.364000      0       0
# 2011-11-01 08:53:07.459000      0       0
# 2011-11-01 08:53:09.284000      0       0
# 2011-11-01 08:54:03.921000      0       0
# 2011-11-01 08:58:06.162000      0       0

# %%
means = df.mean()
means
df.ix[:5] - means
result = df - means
result.mean()
df.corr()
df.T.dot(df)
df2 = df.copy()
df2.ix[:10,0] = np.nan
df2.ix[-10:,1] = np.nan
df2.tail()
#df2.head()
print cov(df2.dropna())
df2.cov()
# ?cov
# Out:
# [[  5.20673868e+04   7.77333968e+04   7.77333968e+04 ...,  -1.48818739e+21
#    -1.48818739e+21  -1.48818739e+21]
#  [  7.77333968e+04   1.16051166e+05   1.16051166e+05 ...,  -2.22177197e+21
#    -2.22177197e+21  -2.22177197e+21]
#  [  7.77333968e+04   1.16051166e+05   1.16051166e+05 ...,  -2.22177197e+21
#    -2.22177197e+21  -2.22177197e+21]
#  ...,
#  [ -1.48818739e+21  -2.22177197e+21  -2.22177197e+21 ...,   4.25352959e+37
#     4.25352959e+37   4.25352959e+37]
#  [ -1.48818739e+21  -2.22177197e+21  -2.22177197e+21 ...,   4.25352959e+37
#     4.25352959e+37   4.25352959e+37]
#  [ -1.48818739e+21  -2.22177197e+21  -2.22177197e+21 ...,   4.25352959e+37
#     4.25352959e+37   4.25352959e+37]]

# %%
print df.ix[:5]
print df.ix[6:11]
print df.ix[:11]
df.ix[:5] + df.ix[6:11]
# Out:
#                              Price  Volume
# ts
# 2011-11-01 08:04:56.364000  104.55     100
# 2011-11-01 08:53:07.459000  104.43     150
# 2011-11-01 08:53:09.284000  104.43     100
# 2011-11-01 08:54:03.921000  104.50     100
# 2011-11-01 08:58:06.162000  104.46    1000
#                                Price  Volume
# ts
# 2011-11-01 08:58:06.162000  104.4600    1000
# 2011-11-01 08:58:06.164000  104.4600    1000
# 2011-11-01 08:58:06.164000  104.4600    1000
# 2011-11-01 09:28:59.153000  104.1700     100
# 2011-11-01 09:29:53.651000  103.3008     426
#                                Price  Volume
# ts
# 2011-11-01 08:04:56.364000  104.5500     100
# 2011-11-01 08:53:07.459000  104.4300     150
# 2011-11-01 08:53:09.284000  104.4300     100
# 2011-11-01 08:54:03.921000  104.5000     100
# 2011-11-01 08:58:06.162000  104.4600    1000
# 2011-11-01 08:58:06.162000  104.4600    1000
# 2011-11-01 08:58:06.162000  104.4600    1000
# 2011-11-01 08:58:06.164000  104.4600    1000
# 2011-11-01 08:58:06.164000  104.4600    1000
# 2011-11-01 09:28:59.153000  104.1700     100
# 2011-11-01 09:29:53.651000  103.3008     426
#                              Price  Volume
# ts
# 2011-11-01 08:04:56.364000     NaN     NaN
# 2011-11-01 08:53:07.459000     NaN     NaN
# 2011-11-01 08:53:09.284000     NaN     NaN
# 2011-11-01 08:54:03.921000     NaN     NaN
# 2011-11-01 08:58:06.162000  208.92    2000
# 2011-11-01 08:58:06.164000     NaN     NaN
# 2011-11-01 08:58:06.164000     NaN     NaN
# 2011-11-01 09:28:59.153000     NaN     NaN
# 2011-11-01 09:29:53.651000     NaN     NaN

# %%
print df.head()
print df.shift().head()

every_other =df.ix[[0,1,2,5,7]]


missing = every_other.reindex(index=df.ix[:20].index)
missing
# Out:
#                              Price  Volume
# ts
# 2011-11-01 08:04:56.364000  104.55     100
# 2011-11-01 08:53:07.459000  104.43     150
# 2011-11-01 08:53:09.284000  104.43     100
# 2011-11-01 08:54:03.921000  104.50     100
# 2011-11-01 08:58:06.162000  104.46    1000
#                              Price  Volume
# ts
# 2011-11-01 08:04:56.364000     NaN     NaN
# 2011-11-01 08:53:07.459000  104.55     100
# 2011-11-01 08:53:09.284000  104.43     150
# 2011-11-01 08:54:03.921000  104.43     100
# 2011-11-01 08:58:06.162000  104.50     100
#                              Price  Volume
# ts
# 2011-11-01 08:04:56.364000  104.55     100
# 2011-11-01 08:53:07.459000  104.43     150
# 2011-11-01 08:53:09.284000  104.43     100
# 2011-11-01 08:54:03.921000     NaN     NaN
# 2011-11-01 08:58:06.162000  104.46    1000
# 2011-11-01 08:58:06.162000  104.46    1000
# 2011-11-01 08:58:06.162000  104.46    1000
# 2011-11-01 08:58:06.164000  104.46    1000
# 2011-11-01 08:58:06.164000  104.46    1000
# 2011-11-01 09:28:59.153000     NaN     NaN
# 2011-11-01 09:29:53.651000     NaN     NaN
# 2011-11-01 09:30:00.278000     NaN     NaN
# 2011-11-01 09:30:00.278000     NaN     NaN
# 2011-11-01 09:30:00.384000     NaN     NaN
# 2011-11-01 09:30:00.384000     NaN     NaN
# 2011-11-01 09:30:00.384000     NaN     NaN
# 2011-11-01 09:30:00.384000     NaN     NaN
# 2011-11-01 09:30:00.384000     NaN     NaN
# 2011-11-01 09:30:00.384000     NaN     NaN
# 2011-11-01 09:30:00.384000     NaN     NaN

# %%
df = ticks.ix[:, ['Price', 'Volume']]
print df
#print df.head()
df2 = ticks.reindex(columns=['Price', 'Volume'])
print df2.head()
df2
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 14632 entries, 2011-11-01 08:04:56.364000 to 2011-11-03 16:09:47.834000
# Data columns:
# Price     14632  non-null values
# Volume    14632  non-null values
# dtypes: float64(1), int64(1)
#                              Price  Volume
# ts
# 2011-11-01 08:04:56.364000  104.55     100
# 2011-11-01 08:53:07.459000  104.43     150
# 2011-11-01 08:53:09.284000  104.43     100
# 2011-11-01 08:54:03.921000  104.50     100
# 2011-11-01 08:58:06.162000  104.46    1000
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 14632 entries, 2011-11-01 08:04:56.364000 to 2011-11-03 16:09:47.834000
# Data columns:
# Price     14632  non-null values
# Volume    14632  non-null values
# dtypes: float64(1), int64(1)

# %%
missing.mean()
missing.values.mean(axis=0)
missing.Price.fillna(method='ffill')
missing.Price.fillna(method='bfill')
print missing.Price.fillna(method='ffill',limit=3)
print missing.Price
# Out:
# ts
# 2011-11-01 08:04:56.364000    104.55
# 2011-11-01 08:53:07.459000    104.43
# 2011-11-01 08:53:09.284000    104.43
# 2011-11-01 08:54:03.921000    104.43
# 2011-11-01 08:58:06.162000    104.46
# 2011-11-01 08:58:06.162000    104.46
# 2011-11-01 08:58:06.162000    104.46
# 2011-11-01 08:58:06.164000    104.46
# 2011-11-01 08:58:06.164000    104.46
# 2011-11-01 09:28:59.153000    104.46
# 2011-11-01 09:29:53.651000    104.46
# 2011-11-01 09:30:00.278000    104.46
# 2011-11-01 09:30:00.278000       NaN
# 2011-11-01 09:30:00.384000       NaN
# 2011-11-01 09:30:00.384000       NaN
# 2011-11-01 09:30:00.384000       NaN
# 2011-11-01 09:30:00.384000       NaN
# 2011-11-01 09:30:00.384000       NaN
# 2011-11-01 09:30:00.384000       NaN
# 2011-11-01 09:30:00.384000       NaN
# Name: Price
# ts
# 2011-11-01 08:04:56.364000    104.55
# 2011-11-01 08:53:07.459000    104.43
# 2011-11-01 08:53:09.284000    104.43
# 2011-11-01 08:54:03.921000       NaN
# 2011-11-01 08:58:06.162000    104.46
# 2011-11-01 08:58:06.162000    104.46
# 2011-11-01 08:58:06.162000    104.46
# 2011-11-01 08:58:06.164000    104.46
# 2011-11-01 08:58:06.164000    104.46
# 2011-11-01 09:28:59.153000       NaN
# 2011-11-01 09:29:53.651000       NaN
# 2011-11-01 09:30:00.278000       NaN
# 2011-11-01 09:30:00.278000       NaN
# 2011-11-01 09:30:00.384000       NaN
# 2011-11-01 09:30:00.384000       NaN
# 2011-11-01 09:30:00.384000       NaN
# 2011-11-01 09:30:00.384000       NaN
# 2011-11-01 09:30:00.384000       NaN
# 2011-11-01 09:30:00.384000       NaN
# 2011-11-01 09:30:00.384000       NaN
# Name: Price

# %%
missing.Price.fillna(missing.Price.mean())
# print missing

# print missing.Price.interpolate()
missing.apply(Series.interpolate)
missing.apply(lambda x: x.interpolate())
missing.dropna()
# Out:
#                              Price  Volume
# ts
# 2011-11-01 08:04:56.364000  104.55     100
# 2011-11-01 08:53:07.459000  104.43     150
# 2011-11-01 08:53:09.284000  104.43     100
# 2011-11-01 08:58:06.162000  104.46    1000
# 2011-11-01 08:58:06.162000  104.46    1000
# 2011-11-01 08:58:06.162000  104.46    1000
# 2011-11-01 08:58:06.164000  104.46    1000
# 2011-11-01 08:58:06.164000  104.46    1000

# %%
# ticks = pd.read_csv(path, parse_dates=['Date'])
df = ticks.ix[:, ['Price', 'Volume']]
df['Returns'] = df.Price.pct_change()
df.head()
# Out:
#     Price  Volume   Returns
# 0  104.55     100       NaN
# 1  104.43     150 -0.001148
# 2  104.43     100  0.000000
# 3  104.50     100  0.000670
# 4  104.46    1000 -0.000383

# %%
ticks.head()
grouped = df.groupby(ticks.Date)
grouped.Returns.agg(lambda x: (1+x).prod() -1)

grouped.agg(lambda x: (x.Price * x.Volume).sum() / x.Volume.sum() )
grouped.agg(lambda x: x.irow(-1)/x.irow(0) -1 )
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9     104.43800
# 10    104.31308
# 11    104.29308
# 12    104.27308
# 13    104.24608
# 14    104.22308
# ...
# 14617    103.804
# 14618    103.802
# 14619    103.800
# 14620    103.800
# 14621    103.800
# 14622    103.800
# 14623    103.800
# 14624    103.800
# 14625    103.802
# 14626    103.808
# 14627    103.808
# 14628    103.809
# 14629    103.810
# 14630    103.811
# 14631    103.812
# Length: 14632

# %%
rs = grouped.transform(lambda x: (x-x.mean()) / x.std() )
rs
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14632 entries, 0 to 14631
# Data columns:
# Price      14632  non-null values
# Volume     14632  non-null values
# Returns    14631  non-null values
# dtypes: float64(3)

# %%
std = ticks.Price.std()
std
# Out:
# 0.19535720037305077

# %%
ticks.to_csv('tmp.csv')

ticks.head()
ticks2 = pd.read_csv('tmp.csv', index_col='ts')
ticks2.head()
# Out:
#                              Price  Volume Exchange Code Sales Condition  \
# ts
# 2011-11-01 08:04:56.364000  104.55     100             P               T
# 2011-11-01 08:53:07.459000  104.43     150             T              FT
# 2011-11-01 08:53:09.284000  104.43     100             T              FT
# 2011-11-01 08:54:03.921000  104.50     100             P              FT
# 2011-11-01 08:58:06.162000  104.46    1000             Z               T
#
#                             Correction Indicator  Sequence Number  \
# ts
# 2011-11-01 08:04:56.364000                     0              196
# 2011-11-01 08:53:07.459000                     0              316
# 2011-11-01 08:53:09.284000                     0              317
# 2011-11-01 08:54:03.921000                     0              318
# 2011-11-01 08:58:06.162000                     0              322
#
#                            Trade Stop Indicator Source of Trade  \
# ts
# 2011-11-01 08:04:56.364000                    N               C
# 2011-11-01 08:53:07.459000                    N               C
# 2011-11-01 08:53:09.284000                    N               C
# 2011-11-01 08:54:03.921000                    N               C
# 2011-11-01 08:58:06.162000                    N               C
#
#                            MDS 127 / TRF (Trade Reporting Facility) (*)  \
# ts
# 2011-11-01 08:04:56.364000                                          NaN
# 2011-11-01 08:53:07.459000                                          NaN
# 2011-11-01 08:53:09.284000                                          NaN
# 2011-11-01 08:54:03.921000                                          NaN
# 2011-11-01 08:58:06.162000                                          NaN
#
#                            Exclude Record Flag  Filtered Price
# ts
# 2011-11-01 08:04:56.364000                 NaN             NaN
# 2011-11-01 08:53:07.459000                 NaN             NaN
# 2011-11-01 08:53:09.284000                 NaN             NaN
# 2011-11-01 08:54:03.921000                 NaN             NaN
# 2011-11-01 08:58:06.162000                 NaN             NaN
